# %% [markdown]
# # EDA - Explanatory data analysis
# This python notebook includes the difference of the datasets interms of aggregations of data fields and tends to set recommendation.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Let me first have the aggregated values from the 3 notebooks of each counry.
# This shall be acheived after consecutively running the notebooks and having the values in our kernel memory.

# %%
from IPython.utils import io

with io.capture_output() as caputred:
    # %run "benin-malanville.ipynb"
    # %run "sierraleone-bumbana.ipynb"
    # %run "togo-dapaong_qc.ipynb"

# %%
# Once I have my computed values in my kernel memory. let me see observe their difference on a line plot

plt.plot(df_benin.describe())
# Out:
# [<matplotlib.lines.Line2D at 0x7f996c1b6b10>,
#  <matplotlib.lines.Line2D at 0x7f9968eb9450>,
#  <matplotlib.lines.Line2D at 0x7f996c05d110>,
#  <matplotlib.lines.Line2D at 0x7f996c05f690>,
#  <matplotlib.lines.Line2D at 0x7f996c05cc10>,
#  <matplotlib.lines.Line2D at 0x7f996c05e510>,
#  <matplotlib.lines.Line2D at 0x7f996c05d190>,
#  <matplotlib.lines.Line2D at 0x7f996c05ddd0>,
#  <matplotlib.lines.Line2D at 0x7f996c05c290>,
#  <matplotlib.lines.Line2D at 0x7f996c194650>,
#  <matplotlib.lines.Line2D at 0x7f996c05f5d0>,
#  <matplotlib.lines.Line2D at 0x7f9968ea6e50>,
#  <matplotlib.lines.Line2D at 0x7f996c05c250>,
#  <matplotlib.lines.Line2D at 0x7f996c05f9d0>,
#  <matplotlib.lines.Line2D at 0x7f996c05ef90>,
#  <matplotlib.lines.Line2D at 0x7f9969170190>,
#  <matplotlib.lines.Line2D at 0x7f9969170a90>]
